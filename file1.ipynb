# %%
# !pip install pymysql sqlalchemy
from sqlalchemy import create_engine
import pandas as pd
# Out:
# ...
# C:\Users\slow\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
MYSQL_HOSTNAME = '34.70.23.130' 
MYSQL_USER = 'steph'
MYSQL_PASSWORD = 'ahi2022'
MYSQL_DATABASE = 'db1'

# %%
connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}/{MYSQL_DATABASE}'
connection_string
# Out:
# 'mysql+pymysql://steph:ahi2022@34.70.23.130/db1'

# %%
db1 = create_engine(connection_string)
db1
# Out:
# Engine(mysql+pymysql://steph:***@34.70.23.130/db1)

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/slow312/HHA-507-2022/main/descriptive/example1/data/Cholesterol.csv')
df1
# Out:
#        Group  Delta
# 0     Active    0.8
# 1     Active    0.9
# 2    Control    1.7
# 3     Active   -1.1
# 4    Control    1.7
# ..       ...    ...
# 295  Control    1.0
# 296   Active    0.4
# 297   Active    1.9
# 298  Control    0.0
# 299   Active   -0.5
#
# [300 rows x 2 columns]

# %%
df1.to_sql('Cholesteral',con=db1,if_exists='replace')
# Out:
# 300

# %%
query1 = """select * from db1.Cholesteral where Delta >= 0.0"""
CL_db_test = pd.read_sql(query1, con=db1)
CL_db_test
# Out:
#      index    Group  Delta
# 0        0   Active    0.8
# 1        1   Active    0.9
# 2        2  Control    1.7
# 3        4  Control    1.7
# 4        7  Control    0.8
# ..     ...      ...    ...
# 155    294   Active    1.2
# 156    295  Control    1.0
# 157    296   Active    0.4
# 158    297   Active    1.9
# 159    298  Control    0.0
#
# [160 rows x 3 columns]

# %%
df2 = pd.read_csv('C:/Users/slow/AHI/HHA-504/mysql-selfmanaged/data/Monkeypox_Research_Summary_Data.csv')
df2
# Out:
#                                     Research Activity  \
# 0                        Vaccine Immunogenicity Study
# 1                         Vaccine Effectiveness Study
# 2        Vaccine Effectiveness Case Series Evaluation
# 3                           Vaccine Utilization Study
# 4                         Vaccine Safety Surveillance
# 5                        Vaccine Immunogenicity Study
# 6                    Next Generation Vaccine Research
# 7                    Next Generation Vaccine Research
# 8                                 Observational Study
# 9                                 Observational Study
# 10                        Serologic assay development
# 11                          Virulence Potential Study
# 12                                 Transmission Study
# 13                       Human-Animal Interface Study
# 14                     Human-Animal Environment Study
# 15                     Human-Animal Environment Study
# ...

# %%
df2 = df2.rename({'Project Title \n(and link to additional information, if available)': 'Project Title'}, axis=1)
df2.columns
# Out:
# Index(['Research Activity', 'Project Title', 'Topic', 'Agency and Office Name',
#        'Country(ies) in which research is/will be conducted', 'Status',
#        'Upcoming Milestones', 'Anticipated Completion', 'Brief Description'],
#       dtype='object')

# %%
df2.to_sql('Monkeypox',con=db1,if_exists='replace')
# Out:
# 45
